# %% [markdown]
# # ETL Project
#
# ## Comparison of closing price between cryptocurrencies and ETFs
#
# #### Adan Bonilla, Morgan Ivey & Orlando Lepe

# %%
# Import dependencies
import pandas as pd
import numpy as np
import os
from sqlalchemy import create_engine
from databaseconfig import user_name, password, local_host
import datetime

# %% [markdown]
# ## Extract CSVs and TXTs into DataFrames
#
# 1. Cryptocurrency Data : [Cryptocurrency Source](
# https://www.kaggle.com/philmohun/cryptocurrency-financial-data)
#
# 2. Stock Data : [Stock Data Source](https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs#aadr.us.txt)

# %%
# Import crypto CSV data
crypto_data = pd.read_csv('Resources/consolidated_coin_data.csv')
crypto_df = crypto_data.copy()

# Convert to Date datetime object
crypto_df['Date']=pd.to_datetime(crypto_df['Date'])

# Find the first and last dates in dataset
first_date_crypto = crypto_df['Date'].iloc[0].strftime('%Y-%m-%d')
last_date_crypto = crypto_df['Date'].iloc[len(crypto_df)-1].strftime('%Y-%m-%d')

# Preview DataFrame
crypto_df.head()
# Out:
#   Currency       Date  Open  High   Low Close      Volume   Market Cap
# 0    tezos 2019-12-04  1.29  1.32  1.25  1.25  46,048,752  824,588,509
# 1    tezos 2019-12-03  1.24  1.32  1.21  1.29  41,462,224  853,213,342
# 2    tezos 2019-12-02  1.25  1.26  1.20  1.24  27,574,097  817,872,179
# 3    tezos 2019-12-01  1.33  1.34  1.25  1.25  24,127,567  828,296,390
# 4    tezos 2019-11-30  1.31  1.37  1.31  1.33  28,706,667  879,181,680

# %%
# Extract the list of file names (<etf>.us.txt)
file_names = os.listdir('Resources/price-volume-data-for-all-us-stocks-etfs/ETFs')
file_names
# Out:
# ['vti.us.txt',
#  'ibnd.us.txt',
#  'viov.us.txt',
#  'urty.us.txt',
#  'schr.us.txt',
#  'jnk.us.txt',
#  'pej.us.txt',
#  'eqwm.us.txt',
#  'rusl.us.txt',
#  'feny.us.txt',
#  'lglv.us.txt',
#  'don.us.txt',
#  'dim.us.txt',
#  'vfh.us.txt',
#  'vug.us.txt',
#  'faus.us.txt',
#  'eelv.us.txt',
#  'vqt.us.txt',
#  'xt.us.txt',
#  'ujb.us.txt',
#  'iwm.us.txt',
#  'uym.us.txt',
#  'fieu.us.txt',
#  'ashs.us.txt',
#  'chim.us.txt',
#  'dia.us.txt',
#  'xtn.us.txt',
#  'agg.us.txt',
#  'tip.us.txt',
#  'gbf.us.txt',
#  'fvd.us.txt',
#  'rvnu.us.txt',
#  'pst.us.txt',
#  'smlf.us.txt',
#  'dnl.us.txt',
#  'know.us.txt',
#  'sil.us.txt',
#  'dxjf.us.txt',
#  'puw.us.txt',
#  'usci.us.txt',
#  'mxi.us.txt',
#  'jjt.us.txt',
#  'gsy.us.txt',
#  'hevy.us.txt',
#  'pvi.us.txt',
#  'sqqq.us.txt',
#  'iwy.us.txt',
#  'hdv.us.txt',
#  'gnma.us.txt',
#  'flot.us.txt',
#  'idv.us.txt',
#  'sdow.us.txt',
#  'ldri.us.txt',
#  'midu.us.txt',
#  'schf.us.txt',
#  'mom.us.txt',
#  'sye.us.txt',
#  'prb.us.txt',
#  'moat.us.txt',
#  'rye.us.txt',
#  'iak.us.txt',
#  'tok.us.txt',
#  'ivw.us.txt',
#  'llsp.us.txt',
#  'eld.us.txt',
#  'pbs.us.txt',
#  'fems.us.txt',
#  'emih.us.txt',
#  'bsjh.us.txt',
#  'bnd.us.txt',
#  'mdyg.us.txt',
#  'vwo.us.txt',
#  'dxj.us.txt',
#  'brzu.us.txt',
#  'dxjr.us.txt',
#  'mdiv.us.txt',
#  'bzf.us.txt',
#  'lstk.us.txt',
#  'geur.us.txt',
#  'jpge.us.txt',
#  'scid.us.txt',
#  'gal.us.txt',
#  'ugld.us.txt',
#  'xsw.us.txt',
#  'ptm.us.txt',
#  'dzz.us.txt',
#  'shv.us.txt',
#  'ffa.us.txt',
#  'inp.us.txt',
#  'koru.us.txt',
#  'slqd.us.txt',
#  'fxi.us.txt',
#  'vxx.us.txt',
#  'flrn.us.txt',
#  'gulf.us.txt',
#  'pdbc.us.txt',
#  'corp.us.txt',
#  'cbon.us.txt',
#  'pplt.us.txt',
#  'soil.us.txt',
#  'epp.us.txt',
#  'iusg.us.txt',
#  'pzt.us.txt',
#  'dgl.us.txt',
#  'agzd.us.txt',
#  'chep.us.txt',
#  'spyg.us.txt',
#  'vig.us.txt',
#  'eum.us.txt',
#  'xhb.us.txt',
#  'soxs.us.txt',
#  'sh.us.txt',
#  'sso.us.txt',
#  'pxh.us.txt',
#  'sds.us.txt',
#  'iscf.us.txt',
#  'ixn.us.txt',
#  'lbj.us.txt',
#  'uup.us.txt',
#  'svxy.us.txt',
#  'govt.us.txt',
#  'smdd.us.txt',
#  'dgro.us.txt',
#  'emcb.us.txt',
#  'fxe.us.txt',
#  'ewq.us.txt',
#  'amu.us.txt',
#  'wmcr.us.txt',
#  'tdtf.us.txt',
#  'dto.us.txt',
#  'fyld.us.txt',
#  'vis.us.txt',
#  'tviz.us.txt',
#  'dbe.us.txt',
#  'tbt.us.txt',
#  'dgrw.us.txt',
#  'qgbr.us.txt',
#  'pcef.us.txt',
#  'ibdb.us.txt',
#  'efv.us.txt',
#  'ubt.us.txt',
#  'xle.us.txt',
#  'sgol.us.txt',
#  'eeh.us.txt',
#  'istb.us.txt',
#  'ure.us.txt',
#  'isra.us.txt',
#  'gqre.us.txt',
#  'foil.us.txt',
#  'eqlt.us.txt',
#  'gyen.us.txt',
#  'pio.us.txt',
#  'eden.us.txt',
#  'ewi.us.txt',
#  'fpxi.us.txt',
#  'bizd.us.txt',
#  'psct.us.txt',
#  'ltl.us.txt',
#  'tlte.us.txt',
#  'uge.us.txt',
#  'dgt.us.txt',
#  'mgc.us.txt',
#  'iyt.us.txt',
#  'syld.us.txt',
#  'xli.us.txt',
#  'ibdn.us.txt',
#  'copx.us.txt',
#  'efz.us.txt',
#  'scj.us.txt',
#  'adre.us.txt',
#  'tbx.us.txt',
#  'mub.us.txt',
#  'erx.us.txt',
#  'csj.us.txt',
#  'ibcc.us.txt',
#  'bsch.us.txt',
#  'fjp.us.txt',
#  'eusa.us.txt',
#  'zsl.us.txt',
#  'wrei.us.txt',
#  'fxg.us.txt',
#  'ews.us.txt',
#  'gxg.us.txt',
#  'ravi.us.txt',
#  'bdcs.us.txt',
#  'iltb.us.txt',
#  'kre.us.txt',
#  'cape.us.txt',
#  'nlr.us.txt',
#  'feuz.us.txt',
#  'drn.us.txt',
#  'pxj.us.txt',
#  'fmk.us.txt',
#  'gval.us.txt',
#  'udow.us.txt',
#  'qcln.us.txt',
#  'ubn.us.txt',
#  'bcm.us.txt',
#  'tur.us.txt',
#  'upro.us.txt',
#  'rwr.us.txt',
#  'pxf.us.txt',
#  'eudg.us.txt',
#  'ftsd.us.txt',
#  'aok.us.txt',
#  'fny.us.txt',
#  'euo.us.txt',
#  'agnd.us.txt',
#  'gasl.us.txt',
#  'aaxj.us.txt',
#  'dbs.us.txt',
#  'qld.us.txt',
#  'ddp.us.txt',
#  'inr.us.txt',
#  'dbmx.us.txt',
#  'vxz.us.txt',
#  'sub.us.txt',
#  'ibdl.us.txt',
#  'mmtm.us.txt',
#  'tfi.us.txt',
#  'acwf.us.txt',
#  'rpg.us.txt',
#  'ihi.us.txt',
#  'xlk.us.txt',
#  'yxi.us.txt',
#  'bscj.us.txt',
#  'def.us.txt',
#  'eusc.us.txt',
#  'actx.us.txt',
#  'size.us.txt',
#  'rwj.us.txt',
#  'dxps.us.txt',
#  'xme.us.txt',
#  'vo.us.txt',
#  'xiv.us.txt',
#  'fhlc.us.txt',
#  'spxs.us.txt',
#  'tecl.us.txt',
#  'pmr.us.txt',
#  'sphb.us.txt',
#  'brf.us.txt',
#  'alts.us.txt',
#  'ewg.us.txt',
#  'fxs.us.txt',
#  'flrt.us.txt',
#  'rek.us.txt',
#  'srty.us.txt',
#  'dgz.us.txt',
#  'ephe.us.txt',
#  'fsta.us.txt',
#  'upw.us.txt',
#  'iyz.us.txt',
#  'cvy.us.txt',
#  'ewk.us.txt',
#  'dbko.us.txt',
#  'dgaz.us.txt',
#  'xlg.us.txt',
#  'ihe.us.txt',
#  'tvix.us.txt',
#  'rcd.us.txt',
#  'drv.us.txt',
#  'csd.us.txt',
#  'hyem.us.txt',
#  'chau.us.txt',
#  'pxr.us.txt',
#  'stpz.us.txt',
#  'nyf.us.txt',
#  'eemv.us.txt',
#  'fpe.us.txt',
#  'afk.us.txt',
#  'rola.us.txt',
#  'ylco.us.txt',
#  'xes.us.txt',
#  'fidu.us.txt',
#  'qed.us.txt',
#  'kfyp.us.txt',
#  'xtl.us.txt',
#  'crbn.us.txt',
#  'vwob.us.txt',
#  'pph.us.txt',
#  'lit.us.txt',
#  'sgdj.us.txt',
#  'faz.us.txt',
#  'fei.us.txt',
#  'rom.us.txt',
#  'iwc.us.txt',
#  'gaz.us.txt',
#  'gru.us.txt',
#  'hyih.us.txt',
#  'pgx.us.txt',
#  'dvyl.us.txt',
#  'emlc.us.txt',
#  'jhdg.us.txt',
#  'fthi.us.txt',
#  'fnde.us.txt',
#  'ldur.us.txt',
#  'atmp.us.txt',
#  'tyo.us.txt',
#  'iwo.us.txt',
#  'qtec.us.txt',
#  'qdf.us.txt',
#  'pbe.us.txt',
#  'ipac.us.txt',
#  'bis.us.txt',
#  'dxjh.us.txt',
#  'fdiv.us.txt',
#  'dbez.us.txt',
#  'dbuk.us.txt',
#  'dol.us.txt',
#  'cyb.us.txt',
#  'schp.us.txt',
#  'ibln.us.txt',
#  'lrgf.us.txt',
#  'fan.us.txt',
#  'icln.us.txt',
#  'idx.us.txt',
#  'dbgr.us.txt',
#  'eirl.us.txt',
#  'vrp.us.txt',
#  'scif.us.txt',
#  'jkl.us.txt',
#  'blv.us.txt',
#  'ulst.us.txt',
#  'iqdf.us.txt',
#  'ftlb.us.txt',
#  'agq.us.txt',
#  'igf.us.txt',
#  'aadr.us.txt',
#  'iev.us.txt',
#  'econ.us.txt',
#  'schh.us.txt',
#  'effe.us.txt',
#  'comt.us.txt',
#  'pxsg.us.txt',
#  'skor.us.txt',
#  'emif.us.txt',
#  'siz.us.txt',
#  'enfr.us.txt',
#  'jo.us.txt',
#  'fgm.us.txt',
#  'jjn.us.txt',
#  'schd.us.txt',
#  'moo.us.txt',
#  'pick.us.txt',
#  'sdiv.us.txt',
#  'dxd.us.txt',
#  'syg.us.txt',
#  'efad.us.txt',
#  'iez.us.txt',
#  'gsc.us.txt',
#  'iai.us.txt',
#  'thd.us.txt',
#  'bsjj.us.txt',
#  'vpl.us.txt',
#  'oef.us.txt',
#  'scij.us.txt',
#  'mna.us.txt',
#  'rxi.us.txt',
#  'fab.us.txt',
#  'cnxt.us.txt',
#  'skf.us.txt',
#  'qdef.us.txt',
#  'ung.us.txt',
#  'umdd.us.txt',
#  'uvxy.us.txt',
#  'heco.us.txt',
#  'ite.us.txt',
#  'fv.us.txt',
#  'epol.us.txt',
#  'ewo.us.txt',
#  'mtum.us.txt',
#  'drr.us.txt',
#  'mvv.us.txt',
#  'usmv.us.txt',
#  'fni.us.txt',
#  'ixp.us.txt',
#  'ydiv.us.txt',
#  'eql.us.txt',
#  'futy.us.txt',
#  'dbc.us.txt',
#  'ibdd.us.txt',
#  'ubr.us.txt',
#  'eeb.us.txt',
#  'ibce.us.txt',
#  'bscn.us.txt',
#  'qdyn.us.txt',
#  'weet.us.txt',
#  'ibdh.us.txt',
#  'dbo.us.txt',
#  'smdv.us.txt',
#  'ewc.us.txt',
#  'srs.us.txt',
#  'vxf.us.txt',
#  'iyr.us.txt',
#  'labu.us.txt',
#  'corn.us.txt',
#  'tdtt.us.txt',
#  'inxx.us.txt',
#  'ymlp.us.txt',
#  'emfm.us.txt',
#  'pie.us.txt',
#  'sbb.us.txt',
#  'ilf.us.txt',
#  'rth.us.txt',
#  'tuz.us.txt',
#  'shyg.us.txt',
#  'ibdp.us.txt',
#  'sgg.us.txt',
#  'tbf.us.txt',
#  'dgre.us.txt',
#  'ieus.us.txt',
#  'igih.us.txt',
#  'sdy.us.txt',
#  'rsxj.us.txt',
#  'flm.us.txt',
#  'qmn.us.txt',
#  'epv.us.txt',
#  'slvo.us.txt',
#  'ttt.us.txt',
#  'gdxs.us.txt',
#  'pscf.us.txt',
#  'iyj.us.txt',
#  'rew.us.txt',
#  'flag.us.txt',
#  'fxo.us.txt',
#  'ivov.us.txt',
#  'fxc.us.txt',
#  'gxc.us.txt',
#  'lmlp.us.txt',
#  'eww.us.txt',
#  'iyf.us.txt',
#  'acwv.us.txt',
#  'dug.us.txt',
#  'bond.us.txt',
#  'ihy.us.txt',
#  'iqlt.us.txt',
#  'eev.us.txt',
#  'bdd.us.txt',
#  'ftsl.us.txt',
#  'dvy.us.txt',
#  'pxmg.us.txt',
#  'vgt.us.txt',
#  'qwld.us.txt',
#  'cefl.us.txt',
#  'vcsh.us.txt',
#  'pff.us.txt',
#  'vonv.us.txt',
#  'pex.us.txt',
#  'ibmh.us.txt',
#  'pak.us.txt',
#  'gsg.us.txt',
#  'tza.us.txt',
#  'fud.us.txt',
#  'ycl.us.txt',
#  'ign.us.txt',
#  'tdiv.us.txt',
#  'usag.us.txt',
#  'vuse.us.txt',
#  'vtwv.us.txt',
#  'ita.us.txt',
#  'scin.us.txt',
#  'fri.us.txt',
#  'jkd.us.txt',
#  'gyld.us.txt',
#  'fieg.us.txt',
#  'psj.us.txt',
#  'gri.us.txt',
#  'socl.us.txt',
#  'vaw.us.txt',
#  'myy.us.txt',
#  'feu.us.txt',
#  'eis.us.txt',
#  'itm.us.txt',
#  'fbt.us.txt',
#  'hold.us.txt',
#  'cane.us.txt',
#  'iws.us.txt',
#  'lalt.us.txt',
#  'hedj.us.txt',
#  'qual.us.txt',
#  'ebnd.us.txt',
#  'jkh.us.txt',
#  'dbef.us.txt',
#  'dln.us.txt',
#  'srln.us.txt',
#  'gwx.us.txt',
#  'eqws.us.txt',
#  'pagg.us.txt',
#  'idlv.us.txt',
#  'fnda.us.txt',
#  'bick.us.txt',
#  'xmlv.us.txt',
#  'smll.us.txt',
#  'fncl.us.txt',
#  'ici.us.txt',
#  'icol.us.txt',
#  'ive.us.txt',
#  'fcom.us.txt',
#  'nfra.us.txt',
#  'ltpz.us.txt',
#  'ext.us.txt',
#  'vgit.us.txt',
#  'schx.us.txt',
#  'ief.us.txt',
#  'uxi.us.txt',
#  'iau.us.txt',
#  'kbwr.us.txt',
#  'idhq.us.txt',
#  'amlp.us.txt',
#  'dod.us.txt',
#  'ipff.us.txt',
#  'fpa.us.txt',
#  'indl.us.txt',
#  'tybs.us.txt',
#  'pgal.us.txt',
#  'sij.us.txt',
#  'totl.us.txt',
#  'usfr.us.txt',
#  'fem.us.txt',
#  'pdn.us.txt',
#  'uyg.us.txt',
#  'psr.us.txt',
#  'dig.us.txt',
#  'ifeu.us.txt',
#  'igv.us.txt',
#  'retl.us.txt',
#  'uhn.us.txt',
#  'figy.us.txt',
#  'dbaw.us.txt',
#  'sjb.us.txt',
#  'xslv.us.txt',
#  'xrlv.us.txt',
#  'xar.us.txt',
#  'sivr.us.txt',
#  'voov.us.txt',
#  'pgf.us.txt',
#  'emb.us.txt',
#  'qqxt.us.txt',
#  'hewg.us.txt',
#  'huse.us.txt',
#  'jkj.us.txt',
#  'smlv.us.txt',
#  'vbk.us.txt',
#  'fbz.us.txt',
#  'pgj.us.txt',
#  'pcy.us.txt',
#  'cupm.us.txt',
#  'chiq.us.txt',
#  'jxi.us.txt',
#  'fad.us.txt',
#  'tna.us.txt',
#  'kxi.us.txt',
#  'jkf.us.txt',
#  'tqqq.us.txt',
#  'slyv.us.txt',
#  'gush.us.txt',
#  'fct.us.txt',
#  'dhs.us.txt',
#  'pbw.us.txt',
#  'bsjl.us.txt',
#  'schb.us.txt',
#  'hao.us.txt',
#  'prf.us.txt',
#  'qai.us.txt',
#  'rjn.us.txt',
#  'pez.us.txt',
#  'lmbs.us.txt',
#  'pwc.us.txt',
#  'psp.us.txt',
#  'feo.us.txt',
#  'fwdi.us.txt',
#  'chii.us.txt',
#  'ezj.us.txt',
#  'gbb.us.txt',
#  'xvz.us.txt',
#  'kbwp.us.txt',
#  'cure.us.txt',
#  'jjp.us.txt',
#  'schz.us.txt',
#  'qus.us.txt',
#  'rzg.us.txt',
#  'efav.us.txt',
#  'inco.us.txt',
#  'ryu.us.txt',
#  'schv.us.txt',
#  'rjz.us.txt',
#  'ring.us.txt',
#  'bjk.us.txt',
#  'fdm.us.txt',
#  'hyls.us.txt',
#  'ifv.us.txt',
#  'szk.us.txt',
#  'bndx.us.txt',
#  'ule.us.txt',
#  'ciu.us.txt',
#  'cmf.us.txt',
#  'fndc.us.txt',
#  'fvl.us.txt',
#  'scix.us.txt',
#  'rly.us.txt',
#  'olem.us.txt',
#  'sly.us.txt',
#  'chie.us.txt',
#  'sdog.us.txt',
#  'rem.us.txt',
#  'vox.us.txt',
#  'croc.us.txt',
#  'uslv.us.txt',
#  'sphd.us.txt',
#  'ewa.us.txt',
#  'mdy.us.txt',
#  'fxu.us.txt',
#  'spxu.us.txt',
#  'wdti.us.txt',
#  'uga.us.txt',
#  'smez.us.txt',
#  'dgp.us.txt',
#  'dirt.us.txt',
#  'sdem.us.txt',
#  'cjnk.us.txt',
#  'finu.us.txt',
#  'rwl.us.txt',
#  'bscl.us.txt',
#  'ibdj.us.txt',
#  'cafe.us.txt',
#  'rigs.us.txt',
#  'mlpx.us.txt',
#  'adra.us.txt',
#  'fmy.us.txt',
#  'tan.us.txt',
#  'fnk.us.txt',
#  'frak.us.txt',
#  'dxge.us.txt',
#  'minc.us.txt',
#  'ura.us.txt',
#  'mcro.us.txt',
#  'dba.us.txt',
#  'dgrs.us.txt',
#  'fif.us.txt',
#  'btal.us.txt',
#  'dwm.us.txt',
#  'fxy.us.txt',
#  'fone.us.txt',
#  'uso.us.txt',
#  'ewm.us.txt',
#  'vclt.us.txt',
#  'ijs.us.txt',
#  'sea.us.txt',
#  'vot.us.txt',
#  'wood.us.txt',
#  'feeu.us.txt',
#  'mgk.us.txt',
#  'pzd.us.txt',
#  'mrgr.us.txt',
#  'xly.us.txt',
#  'rdiv.us.txt',
#  'sret.us.txt',
#  'adru.us.txt',
#  'scz.us.txt',
#  'dfj.us.txt',
#  'rgi.us.txt',
#  'cwi.us.txt',
#  'vthr.us.txt',
#  'argt.us.txt',
#  'rwx.us.txt',
#  'aoa.us.txt',
#  'dag.us.txt',
#  'lvl.us.txt',
#  'eet.us.txt',
#  'ixj.us.txt',
#  'rfg.us.txt',
#  'hyd.us.txt',
#  'psch.us.txt',
#  'edz.us.txt',
#  'fxa.us.txt',
#  'drip.us.txt',
#  'ewu.us.txt',
#  'ijk.us.txt',
#  'inkm.us.txt',
#  'enzl.us.txt',
#  'vtip.us.txt',
#  'ewy.us.txt',
#  'pxlg.us.txt',
#  'pscd.us.txt',
#  'iyh.us.txt',
#  'yyy.us.txt',
#  'edv.us.txt',
#  'gunr.us.txt',
#  'ipkw.us.txt',
#  'acwx.us.txt',
#  'ftcs.us.txt',
#  'xlu.us.txt',
#  'spy.us.txt',
#  'mbb.us.txt',
#  'frel.us.txt',
#  'aom.us.txt',
#  'fcan.us.txt',
#  'cbnd.us.txt',
#  'cper.us.txt',
#  'xmpt.us.txt',
#  'bsv.us.txt',
#  'ssg.us.txt',
#  'fyc.us.txt',
#  'ewh.us.txt',
#  'pxlv.us.txt',
#  'mbsd.us.txt',
#  'kroo.us.txt',
#  'fmat.us.txt',
#  'iyy.us.txt',
#  'pscu.us.txt',
#  'pjp.us.txt',
#  'ddg.us.txt',
#  'pza.us.txt',
#  'fill.us.txt',
#  'pin.us.txt',
#  'pxq.us.txt',
#  'ioil.us.txt',
#  'ibdc.us.txt',
#  'qls.us.txt',
#  'acwi.us.txt',
#  'vgsh.us.txt',
#  'erus.us.txt',
#  'remx.us.txt',
#  'nugt.us.txt',
#  'ihf.us.txt',
#  'bwx.us.txt',
#  'ery.us.txt',
#  'uag.us.txt',
#  'bsci.us.txt',
#  'adrd.us.txt',
#  'ibdo.us.txt',
#  'emag.us.txt',
#  'fxp.us.txt',
#  'jpmv.us.txt',
#  'ewd.us.txt',
#  'axjv.us.txt',
#  'tltd.us.txt',
#  'rfv.us.txt',
#  'ugaz.us.txt',
#  'epi.us.txt',
#  'slvp.us.txt',
#  'cntr.us.txt',
#  'dbp.us.txt',
#  'fiw.us.txt',
#  'robo.us.txt',
#  'xlp.us.txt',
#  'mbg.us.txt',
#  'lemb.us.txt',
#  'ixc.us.txt',
#  'trsk.us.txt',
#  'carz.us.txt',
#  'pxe.us.txt',
#  'zmlp.us.txt',
#  'vt.us.txt',
#  'qqqe.us.txt',
#  'fhy.us.txt',
#  'spxh.us.txt',
#  'uco.us.txt',
#  'fxh.us.txt',
#  'twm.us.txt',
#  'near.us.txt',
#  'uwm.us.txt',
#  'imtm.us.txt',
#  'voe.us.txt',
#  'iym.us.txt',
#  'ucc.us.txt',
#  'tflo.us.txt',
#  'gdxx.us.txt',
#  'eufx.us.txt',
#  'asea.us.txt',
#  'mgv.us.txt',
#  'dtn.us.txt',
#  'pscm.us.txt',
#  'udn.us.txt',
#  'ewp.us.txt',
#  'fxd.us.txt',
#  'oil.us.txt',
#  'lqd.us.txt',
#  'ubm.us.txt',
#  'efo.us.txt',
#  'mlpi.us.txt',
#  'vcit.us.txt',
#  'weat.us.txt',
#  'dbem.us.txt',
#  'mchi.us.txt',
#  'bsji.us.txt',
#  'tlt.us.txt',
#  'fgb.us.txt',
#  'jjm.us.txt',
#  'schg.us.txt',
#  'ivv.us.txt',
#  'dsum.us.txt',
#  'xrt.us.txt',
#  'amjl.us.txt',
#  'cly.us.txt',
#  'hgi.us.txt',
#  'gaa.us.txt',
#  'iwx.us.txt',
#  'grn.us.txt',
#  'frn.us.txt',
#  'qyld.us.txt',
#  'grwn.us.txt',
#  'ige.us.txt',
#  'chix.us.txt',
#  'tmv.us.txt',
#  'iqde.us.txt',
#  'egpt.us.txt',
#  'xph.us.txt',
#  'qjpn.us.txt',
#  'rdvy.us.txt',
#  'fam.us.txt',
#  'eny.us.txt',
#  'vioo.us.txt',
#  'qlta.us.txt',
#  'dxjs.us.txt',
#  'pfm.us.txt',
#  'fta.us.txt',
#  'xbi.us.txt',
#  'eema.us.txt',
#  'qqq.us.txt',
#  'rzv.us.txt',
#  'fcor.us.txt',
#  'jja.us.txt',
#  'ryh.us.txt',
#  'iemg.us.txt',
#  'iwl.us.txt',
#  'fbnd.us.txt',
#  'ashr.us.txt',
#  'jnug.us.txt',
#  'gvi.us.txt',
#  'fndf.us.txt',
#  'xpp.us.txt',
#  'kold.us.txt',
#  'hyzd.us.txt',
#  'nfo.us.txt',
#  'stip.us.txt',
#  'acim.us.txt',
#  'sagg.us.txt',
#  'choc.us.txt',
#  'yao.us.txt',
#  'doo.us.txt',
#  'pek.us.txt',
#  'eqwl.us.txt',
#  'gltr.us.txt',
#  'ziv.us.txt',
#  'plnd.us.txt',
#  'slyg.us.txt',
#  'gce.us.txt',
#  'vone.us.txt',
#  'fdd.us.txt',
#  'qat.us.txt',
#  'jju.us.txt',
#  'pbj.us.txt',
#  'nobl.us.txt',
#  'vgk.us.txt',
#  'dbeu.us.txt',
#  'fpf.us.txt',
#  'cmdt.us.txt',
#  'vegi.us.txt',
#  'viix.us.txt',
#  'ycs.us.txt',
#  'wdiv.us.txt',
#  'voog.us.txt',
#  'sjnk.us.txt',
#  'agf.us.txt',
#  'ftc.us.txt',
#  'dbap.us.txt',
#  'smh.us.txt',
#  'midz.us.txt',
#  'jjc.us.txt',
#  'ryj.us.txt',
#  'exi.us.txt',
#  'muni.us.txt',
#  'vdc.us.txt',
#  'mort.us.txt',
#  'div.us.txt',
#  'hymb.us.txt',
#  'ezy.us.txt',
#  'iwv.us.txt',
#  'rxd.us.txt',
#  'reet.us.txt',
#  'ezu.us.txt',
#  'rals.us.txt',
#  'pgm.us.txt',
#  'shy.us.txt',
#  'idu.us.txt',
#  'bkln.us.txt',
#  'vglt.us.txt',
#  'vea.us.txt',
#  'fep.us.txt',
#  'pbp.us.txt',
#  'bsjk.us.txt',
#  'phdg.us.txt',
#  'rji.us.txt',
#  'heem.us.txt',
#  'roof.us.txt',
#  'yinn.us.txt',
#  'ryf.us.txt',
#  'sche.us.txt',
#  'vlue.us.txt',
#  'dgld.us.txt',
#  'vss.us.txt',
#  'iwb.us.txt',
#  'dno.us.txt',
#  'viiz.us.txt',
#  'edog.us.txt',
#  'ipo.us.txt',
#  'dvya.us.txt',
#  'mzz.us.txt',
#  'qefa.us.txt',
#  'hdge.us.txt',
#  'ezm.us.txt',
#  'imlp.us.txt',
#  'fsz.us.txt',
#  'hap.us.txt',
#  'math.us.txt',
#  'bzq.us.txt',
#  'vpu.us.txt',
#  'ftw.us.txt',
#  'fxch.us.txt',
#  'ifgl.us.txt',
#  'morl.us.txt',
#  'ieo.us.txt',
#  'dls.us.txt',
#  'fcg.us.txt',
#  'pbd.us.txt',
#  'vong.us.txt',
#  'hspx.us.txt',
#  'ibb.us.txt',
#  'kie.us.txt',
#  'hynd.us.txt',
#  'veu.us.txt',
#  'djp.us.txt',
#  'fwdb.us.txt',
#  'iwn.us.txt',
#  'spuu.us.txt',
#  'guru.us.txt',
#  'skyy.us.txt',
#  'eza.us.txt',
#  'shm.us.txt',
#  'vtwg.us.txt',
#  'fxr.us.txt',
#  'usd.us.txt',
#  'tyns.us.txt',
#  'eurl.us.txt',
#  'iyw.us.txt',
#  'eufn.us.txt',
#  'dpk.us.txt',
#  'kba.us.txt',
#  'ivog.us.txt',
#  'qaba.us.txt',
#  'igov.us.txt',
#  'sdd.us.txt',
#  'vnq.us.txt',
#  'aor.us.txt',
#  'uae.us.txt',
#  'iefa.us.txt',
#  'bsck.us.txt',
#  'vym.us.txt',
#  'rsx.us.txt',
#  'pxmv.us.txt',
#  'bwz.us.txt',
#  'rwk.us.txt',
#  'ibdm.us.txt',
#  'emsh.us.txt',
#  'vxus.us.txt',
#  'bwv.us.txt',
#  'drw.us.txt',
#  'byld.us.txt',
#  'cn.us.txt',
#  'xlf.us.txt',
#  'wip.us.txt',
#  'efu.us.txt',
#  'phb.us.txt',
#  'mlps.us.txt',
#  'cew.us.txt',
#  'ftec.us.txt',
#  'sef.us.txt',
#  'ewj.us.txt',
#  'tusa.us.txt',
#  'ijt.us.txt',
#  'ech.us.txt',
#  'upv.us.txt',
#  'vb.us.txt',
#  'fltb.us.txt',
#  'ees.us.txt',
#  'zroz.us.txt',
#  'des.us.txt',
#  'sdp.us.txt',
#  'ero.us.txt',
#  'boil.us.txt',
#  'tolz.us.txt',
#  'lowc.us.txt',
#  'gld.us.txt',
#  'vlu.us.txt',
#  'gxf.us.txt',
#  'fxf.us.txt',
#  'ayt.us.txt',
#  'iyc.us.txt',
#  'labd.us.txt',
#  ...]

# %%
# Create empty DataFrame (main DataFrame for ETFs) 
all_stocks = pd.DataFrame(columns=['Date','Open','High','Low','Close','Volume','OpenInt','ETF'])

# Append each .txt file to main DataFrame, account for/skip empty files
for file in file_names:
    if os.stat(f'Resources/price-volume-data-for-all-us-stocks-etfs/ETFs/{file}').st_size > 0:
        stock_data = pd.read_csv(f'Resources/price-volume-data-for-all-us-stocks-etfs/ETFs/{file}')
        stock_data['ETF'] = file.split('.')[0]
        stock_data = stock_data[stock_data['Date']>=last_date_crypto]
        all_stocks = all_stocks.append(stock_data)
    else:
        print(f'Empty File : {file}')

# Export stock DataFrame to csv file 
all_stocks.to_csv('Resources/all_etf_data.csv')

# %%
# Preview all_stocks DataFrame
all_stocks.head()
# Out:
#             Date    Open    High     Low   Close   Volume OpenInt  ETF
# 2055  2013-04-29  74.952  75.393  74.842  75.227  2309512       0  vti
# 2056  2013-04-30  75.242  75.488  74.936  75.452  1897648       0  vti
# 2057  2013-05-01  75.319  75.375  74.649  74.688  2354331       0  vti
# 2058  2013-05-02  74.861  75.511  74.861  75.466  1761879       0  vti
# 2059  2013-05-03  76.127  76.484  76.006  76.172  2597651       0  vti

# %%
# Extract the Stock CSV
all_stock_df = pd.read_csv('Resources/all_etf_data.csv')
all_stock_df.head()
# Out:
#    Unnamed: 0        Date    Open    High     Low   Close   Volume  OpenInt  \
# 0        2055  2013-04-29  74.952  75.393  74.842  75.227  2309512        0
# 1        2056  2013-04-30  75.242  75.488  74.936  75.452  1897648        0
# 2        2057  2013-05-01  75.319  75.375  74.649  74.688  2354331        0
# 3        2058  2013-05-02  74.861  75.511  74.861  75.466  1761879        0
# 4        2059  2013-05-03  76.127  76.484  76.006  76.172  2597651        0
#
#    ETF
# 0  vti
# 1  vti
# 2  vti
# 3  vti
# 4  vti

# %% [markdown]
# ## Transform the ETF DataFrame

# %%
# Change the date column to datetime (format %Y-%m-%d)
all_stock_df['Date'] = pd.to_datetime(all_stock_df['Date'])

# %% [markdown]
# ## Transform the Cryptocurrency DataFrame

# %%
# Convert date to match ETF's datetime (format %Y-%m-%d)
crypto_df['Date'] = pd.to_datetime(crypto_df['Date'])

# Sort date values by Date
crypto_df = crypto_df.sort_values(by=["Date"])

# Preview cryptocurrency DataFrame
crypto_df.head()
# Out:
#        Currency       Date    Open    High     Low   Close Volume  \
# 14471       xrp 2013-04-28  135.30  135.98  132.10  134.21      0
# 26531   cardano 2013-04-28    4.30    4.40    4.18    4.35      0
# 24119  ethereum 2013-04-28  135.30  135.98  132.10  134.21      0
# 21707  litecoin 2013-04-28    4.30    4.40    4.18    4.35      0
# 19295   stellar 2013-04-28    4.30    4.40    4.18    4.35      0
#
#           Market Cap
# 14471  1,488,566,728
# 26531     74,636,938
# 24119  1,488,566,728
# 21707     74,636,938
# 19295     74,636,938

# %% [markdown]
# ## Create and Transform the Merged DataFrame

# %%
# Merge the two DataFrames on Date
stock_crypto_df = all_stock_df.merge(crypto_df,on=['Date'])

# Drop the old index of the stock DataFrame and set the new index to be Date
stock_crypto_df = stock_crypto_df.drop(columns=['Unnamed: 0'])

# Rename the columns to specify _Stock and _Crypto
stock_crypto_df.columns = stock_crypto_df.columns.str.replace('_x','_etf').str.replace('_y','_crypto')

# Extract the list of column names to reorder the columns 
col_list = list(stock_crypto_df.columns.values)
stock_index = col_list.index("ETF")
reordered_cols = [col_list[0]] + [col_list[stock_index]]+ col_list[1:(stock_index)]+ col_list[(stock_index+1):]
stock_crypto_df = stock_crypto_df[reordered_cols]

# Preview the merged dataframe with reordered columns
stock_crypto_df.head()
# Out:
#         Date  ETF  Open_etf  High_etf  Low_etf  Close_etf  Volume_etf  \
# 0 2013-04-29  vti    74.952    75.393   74.842     75.227     2309512
# 1 2013-04-29  vti    74.952    75.393   74.842     75.227     2309512
# 2 2013-04-29  vti    74.952    75.393   74.842     75.227     2309512
# 3 2013-04-29  vti    74.952    75.393   74.842     75.227     2309512
# 4 2013-04-29  vti    74.952    75.393   74.842     75.227     2309512
#
#    OpenInt      Currency Open_crypto High_crypto Low_crypto Close_crypto  \
# 0        0    bitcoin-sv        4.37        4.57       4.23         4.38
# 1        0      ethereum      134.44      147.49     134.00       144.54
# 2        0  bitcoin-cash      134.44      147.49     134.00       144.54
# 3        0         tezos        4.37        4.57       4.23         4.38
# 4        0           xrp      134.44      147.49     134.00       144.54
#
#   Volume_crypto     Market Cap
# 0             0     75,388,964
# 1             0  1,603,768,865
# 2             0  1,603,768,865
# 3             0     75,388,964
# 4             0  1,603,768,865

# %%
# Filter DataFrame to only show closing price of ETF and Cryptocurrency
stock_crypto_df_short = stock_crypto_df[['Date','ETF','Close_etf','Currency','Close_crypto']]

# Convert date to string for loading into SQL's date type
stock_crypto_df_short["Date"] = stock_crypto_df_short["Date"].dt.strftime('%Y-%m-%d')

# Rename columns to match SQL's lower case
stock_crypto_df_short = stock_crypto_df_short.rename(columns={'Date':'date_','ETF':'etf','Close_etf':'close_etf','Currency':'currency','Close_crypto':'close_crypto'})

# Convert closing price to type numeric (no thousands place commas)
stock_crypto_df_short['close_crypto'] = stock_crypto_df_short['close_crypto'].str.replace(',','')

# Preview final DataFrame
stock_crypto_df_short.head()
# Out:
# /Users/morganivey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#         date_  etf  close_etf      currency close_crypto
# 0  2013-04-29  vti     75.227    bitcoin-sv         4.38
# 1  2013-04-29  vti     75.227      ethereum       144.54
# 2  2013-04-29  vti     75.227  bitcoin-cash       144.54
# 3  2013-04-29  vti     75.227         tezos         4.38
# 4  2013-04-29  vti     75.227           xrp       144.54

# %%
# Save DataFrame to CSV file
stock_crypto_df_short.to_csv('Resources/condensed_ETF_crypto.csv')

# %%
len(stock_crypto_df_short)
# Out:
# 16530388

# %% [markdown]
# ## Load Transformed DataFrame to PostgreSQL
#
# ### Create database connection

# %%
# Connect to the database
connection_string = f'postgresql://{user_name}:{password}@{local_host}/stocks_db'
engine = create_engine(connection_string)

# %%
# List the table names in stocks_db database
engine.table_names()
# Out:
# ['stocks_merged']

# %% [markdown]
# ### Load DataFrames into database

# %%
stock_crypto_df_short.to_sql(name='stocks_merged', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the stock_crypto table

# %%
pd.read_sql_query('select * from stocks_merged', con=engine)
# Out:
#                date_   etf  close_etf      currency  close_crypto
# 0         2013-04-29   vti     75.227    bitcoin-sv      4.380000
# 1         2013-04-29   vti     75.227      ethereum    144.540000
# 2         2013-04-29   vti     75.227  bitcoin-cash    144.540000
# 3         2013-04-29   vti     75.227         tezos      4.380000
# 4         2013-04-29   vti     75.227           xrp    144.540000
# 5         2013-04-29   vti     75.227       bitcoin    144.540000
# 6         2013-04-29   vti     75.227      litecoin      4.380000
# 7         2013-04-29   vti     75.227           eos      4.380000
# 8         2013-04-29   vti     75.227        tether    144.540000
# 9         2013-04-29   vti     75.227       stellar      4.380000
# 10        2013-04-29   vti     75.227       cardano      4.380000
# 11        2013-04-29   vti     75.227  binance-coin      4.380000
# 12        2013-04-29  ibnd     34.342    bitcoin-sv      4.380000
# 13        2013-04-29  ibnd     34.342      ethereum    144.540000
# 14        2013-04-29  ibnd     34.342  bitcoin-cash    144.540000
# 15        2013-04-29  ibnd     34.342         tezos      4.380000
# 16        2013-04-29  ibnd     34.342           xrp    144.540000
# 17        2013-04-29  ibnd     34.342       bitcoin    144.540000
# 18        2013-04-29  ibnd     34.342      litecoin      4.380000
# 19        2013-04-29  ibnd     34.342           eos      4.380000
# 20        2013-04-29  ibnd     34.342        tether    144.540000
# 21        2013-04-29  ibnd     34.342       stellar      4.380000
# 22        2013-04-29  ibnd     34.342       cardano      4.380000
# 23        2013-04-29  ibnd     34.342  binance-coin      4.380000
# 24        2013-04-29  urty     24.054    bitcoin-sv      4.380000
# 25        2013-04-29  urty     24.054      ethereum    144.540000
# 26        2013-04-29  urty     24.054  bitcoin-cash    144.540000
# 27        2013-04-29  urty     24.054         tezos      4.380000
# 28        2013-04-29  urty     24.054           xrp    144.540000
# 29        2013-04-29  urty     24.054       bitcoin    144.540000
# ...              ...   ...        ...           ...           ...
# 16530358  2017-11-10  emlp     24.600      litecoin     59.260000
# 16530359  2017-11-10  emlp     24.600  binance-coin      1.800000
# 16530360  2017-11-10  emlp     24.600      ethereum    299.250000
# 16530361  2017-11-10  emlp     24.600        tether      1.010000
# 16530362  2017-11-10  emlp     24.600           eos      1.030000
# 16530363  2017-11-10  emlp     24.600         tezos      1.560000
# 16530364  2017-11-10   agz    113.240       cardano      0.027119
# 16530365  2017-11-10   agz    113.240  bitcoin-cash   1007.420000
# 16530366  2017-11-10   agz    113.240    bitcoin-sv      1.800000
# 16530367  2017-11-10   agz    113.240           xrp      0.206483
# 16530368  2017-11-10   agz    113.240       bitcoin   6618.140000
# 16530369  2017-11-10   agz    113.240       stellar      0.033073
# 16530370  2017-11-10   agz    113.240      litecoin     59.260000
# 16530371  2017-11-10   agz    113.240  binance-coin      1.800000
# 16530372  2017-11-10   agz    113.240      ethereum    299.250000
# 16530373  2017-11-10   agz    113.240        tether      1.010000
# 16530374  2017-11-10   agz    113.240           eos      1.030000
# 16530375  2017-11-10   agz    113.240         tezos      1.560000
# 16530376  2017-11-10   igm    167.900       cardano      0.027119
# 16530377  2017-11-10   igm    167.900  bitcoin-cash   1007.420000
# 16530378  2017-11-10   igm    167.900    bitcoin-sv      1.800000
# 16530379  2017-11-10   igm    167.900           xrp      0.206483
# 16530380  2017-11-10   igm    167.900       bitcoin   6618.140000
# 16530381  2017-11-10   igm    167.900       stellar      0.033073
# 16530382  2017-11-10   igm    167.900      litecoin     59.260000
# 16530383  2017-11-10   igm    167.900  binance-coin      1.800000
# 16530384  2017-11-10   igm    167.900      ethereum    299.250000
# 16530385  2017-11-10   igm    167.900        tether      1.010000
# 16530386  2017-11-10   igm    167.900           eos      1.030000
# 16530387  2017-11-10   igm    167.900         tezos      1.560000
#
# [16530388 rows x 5 columns]
